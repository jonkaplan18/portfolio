# %% [markdown]
# # **Worlds Without End Scraper for Author Demographics**
# Jon Kaplan
#
# Run these steps first since both the review and book info scraper use these

# %% [markdown]
# > ### 1) Install and Load Necessary Libraries

# %%
# STEP 1 libraries

#https://github.com/williecostello/GoodReadsReviewsScraper

#libraries
# !pip install selenium
import os
import pandas as pd
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from datetime import datetime
import numpy as np
import time
import requests
import urllib.request as urllib2
import xml.etree.ElementTree as ET
from urllib.request import urlopen
# Out:
# ...
#      |████████████████████████████████| 911kB 8.7MB/s
# ...

# %%
# STEP 2 directory 

# google drive and change directory, otherwise will just output csvs to google colab files

from google.colab import drive
drive.mount('/content/drive')

# change directory to wherever you want output
# %cd /content/drive/My\ Drive/Colab\ Notebooks/IST718/FinalProject/GoodReads/GoodReadsScraper3

# %% [markdown]
# > ### 2) Install Selenium and Chromedriver

# %%
# STEP 3 install requirements and chromium/selenium

# # install requirements
# beautifulsoup4==4.9.1
# numpy==1.18.3
# pandas==1.0.3
# selenium==3.141.0

# install chromium, its driver, and selenium

# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
# chromepath = webdriver.Chrome('chromedriver',options=options)
# wd.get("https://www.google.com")
# print(wd.page_source)  # results
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension adobe-flashplugin
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 43 not upgraded.
# Need to get 75.5 MB of archives.
# After this operation, 256 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 83.0.4103.61-0ubuntu0.18.04.1 [1,119 kB]
# ...

# %%
# # urls
# from bs4 import BeautifulSoup
# page = urlopen("http://www.worldswithoutend.com/authors_index.asp")
# soup = BeautifulSoup(page.read())
# links = soup.find_all('a')
# links=links.find_all('href"')

# html = urlopen("http://kite.com")
# soup = BeautifulSoup(html.read(), 'lxml')
# links = []
# for link in soup.find_all('a'):
#     links.append(link.get('href'))

# %%
# gets all URLs WORKS
html = urlopen("http://www.worldswithoutend.com/authors_index.asp")
soup = BeautifulSoup(html.read(), 'lxml')
links = []
for link in soup.find_all('a'):
    links.append(link.get('href'))

# %%
links
# Out:
# [None,
#  "javascript:switchBG('01');",
#  "javascript:switchBG('02');",
#  "javascript:switchBG('03');",
#  "javascript:switchBG('04');",
#  "javascript:switchBG('05');",
#  "javascript:switchBG('06');",
#  "javascript:switchBG('07');",
#  "javascript:switchBG('08');",
#  "javascript:switchBG('09');",
#  "javascript:switchBG('10');",
#  "javascript:switchBG('11');",
#  'javascript:void(0);',
#  '/index.asp',
#  '/searchwwe.asp?st=',
#  '/books.asp',
#  '/books.asp',
#  '/books_hugo_index.asp',
#  '/books_nebula_index.asp',
#  '/books_bsfa_index.asp',
#  '/books_mytho_index.asp',
#  '/books_locus-sf_index.asp',
#  '/books_bfs-derleth_index.asp',
#  '/books_campbell_index.asp',
#  '/books_wfa_index.asp',
#  '/books_locus-f_index.asp',
#  '/books_prometheus_index.asp',
#  '/books_locus-fn_index.asp',
#  '/books_aurora_index.asp',
#  '/books_pkd_index.asp',
#  '/books_clarke_index.asp',
#  '/books_stoker_index.asp',
#  '/books_otherwise_index.asp',
#  '/books_aurealis-sf_index.asp',
# ...

# %%
bookurls=links

book_urls=[]

for link in bookurls:
  book_urls.append('http://www.worldswithoutend.com/' +str(link))

# %%
book_urls
# Out:
# ['http://www.worldswithoutend.com/None',
#  "http://www.worldswithoutend.com/javascript:switchBG('01');",
#  "http://www.worldswithoutend.com/javascript:switchBG('02');",
#  "http://www.worldswithoutend.com/javascript:switchBG('03');",
#  "http://www.worldswithoutend.com/javascript:switchBG('04');",
#  "http://www.worldswithoutend.com/javascript:switchBG('05');",
#  "http://www.worldswithoutend.com/javascript:switchBG('06');",
#  "http://www.worldswithoutend.com/javascript:switchBG('07');",
#  "http://www.worldswithoutend.com/javascript:switchBG('08');",
#  "http://www.worldswithoutend.com/javascript:switchBG('09');",
#  "http://www.worldswithoutend.com/javascript:switchBG('10');",
#  "http://www.worldswithoutend.com/javascript:switchBG('11');",
#  'http://www.worldswithoutend.com/javascript:void(0);',
#  'http://www.worldswithoutend.com//index.asp',
#  'http://www.worldswithoutend.com//searchwwe.asp?st=',
#  'http://www.worldswithoutend.com//books.asp',
# ...

# %%
# href_tags = soup.find_all(href=True)   
# hrefs = [tag.get('href') for tag in href_tags]

# %%
bookurls=href

book_urls=[]

for link in bookurls:
  book_urls.append('http://www.worldswithoutend.com/' +link)

# %%
book_urls
# Out:
# ['http://www.worldswithoutend.com/author.asp?ID=1860',
#  'http://www.worldswithoutend.com/author.asp?ID=1718',
#  'http://www.worldswithoutend.com/author.asp?ID=4462',
#  'http://www.worldswithoutend.com/author.asp?ID=2439',
#  'http://www.worldswithoutend.com/author.asp?ID=1613',
#  'http://www.worldswithoutend.com/author.asp?ID=5001',
#  'http://www.worldswithoutend.com/author.asp?ID=5719',
#  'http://www.worldswithoutend.com/author.asp?ID=2472',
#  'http://www.worldswithoutend.com/author.asp?ID=1177',
#  'http://www.worldswithoutend.com/author.asp?ID=1221',
#  'http://www.worldswithoutend.com/author.asp?ID=4626',
#  'http://www.worldswithoutend.com/author.asp?ID=1074',
#  'http://www.worldswithoutend.com/author.asp?ID=4890',
#  'http://www.worldswithoutend.com/author.asp?ID=3872',
#  'http://www.worldswithoutend.com/author.asp?ID=3707',
#  'http://www.worldswithoutend.com/author.asp?ID=5634',
#  'http://www.worldswithoutend.com/author.asp?ID=1770',
# ...

# %% [markdown]
# > ### 3) Input GoodReads Book URLs

# %%
# URL LINKS

href=['author.asp?ID=1860',
 'author.asp?ID=1718',
 'author.asp?ID=4462',
 'author.asp?ID=2439',
 'author.asp?ID=1613',
 'author.asp?ID=5001',
 'author.asp?ID=5719',
 'author.asp?ID=2472',
 'author.asp?ID=3204',
 'author.asp?ID=4460',
 'author.asp?ID=3467',
 'author.asp?ID=7657',
 'author.asp?ID=5599',
 'author.asp?ID=7391',
 'author.asp?ID=310',
 'author.asp?ID=17',
 'author.asp?ID=6150',
 'author.asp?ID=3000',
 'author.asp?ID=4102',
 'author.asp?ID=2050',
 'author.asp?ID=2480',
 'author.asp?ID=6140',
 'author.asp?ID=2407',
 'author.asp?ID=1422',
 'author.asp?ID=4064',
 'author.asp?ID=7219',
 'author.asp?ID=2341',
 'author.asp?ID=993',
 'author.asp?ID=460',
 'author.asp?ID=7554',
 'author.asp?ID=2142',
 'author.asp?ID=167',
 'author.asp?ID=459',
 'author.asp?ID=1794',
 'author.asp?ID=4328',
 'author.asp?ID=1939',
 'author.asp?ID=39',
 'author.asp?ID=7208',
 'author.asp?ID=1444',
 'author.asp?ID=2332',
 'author.asp?ID=5511',
 'author.asp?ID=97',
 'author.asp?ID=1220',
 'author.asp?ID=3278',
 'author.asp?ID=1279',
 'author.asp?ID=514',
 'author.asp?ID=5548',
 'author.asp?ID=5630',
 'author.asp?ID=3072',
 'author.asp?ID=6133',
 'author.asp?ID=4149',
 'author.asp?ID=4422',
 'author.asp?ID=3177',
 'author.asp?ID=4698',
 'author.asp?ID=4946',
 'author.asp?ID=5157',
 'author.asp?ID=5232',
 'author.asp?ID=5653',
 'author.asp?ID=7708',
 'author.asp?ID=1300',
 'author.asp?ID=2733',
 'author.asp?ID=479',
 'author.asp?ID=5495',
 'author.asp?ID=836',
 'author.asp?ID=1240',
 'author.asp?ID=2092',
 'author.asp?ID=4369',
 'author.asp?ID=7250',
 'author.asp?ID=5292',
 'author.asp?ID=2446',
 'author.asp?ID=1222',
 'author.asp?ID=1280',
 'author.asp?ID=137',
 'author.asp?ID=3465',
 'author.asp?ID=4169',
 'author.asp?ID=4056',
 'author.asp?ID=7363',
 'author.asp?ID=5569',
 'author.asp?ID=4384',
 'author.asp?ID=3698',
 'author.asp?ID=4741',
 'author.asp?ID=7465',
 'author.asp?ID=3816',
 'author.asp?ID=3681']

# filtering bookIDs so only scrape each bookID once
import pandas as pd
import numpy as np

# make list of urls from bookLink column

bookurls=href

book_urls=[]

for link in bookurls:
  book_urls.append('http://www.worldswithoutend.com/' +link)

zzz = 4

chromepath = webdriver.Chrome('chromedriver',options=options)

# %%
# # STEP 4 scrapper settings and URLS (Input your goodreads URLS here)

# # Set local path of chromedriver
# # chrome_path = '/Library/chromedriver'
# chromepath = webdriver.Chrome('chromedriver',options=options)

# # Set list of book URLs to be scraped (Nebula nominees)
# # (All URLs should begin with 'https://www.goodreads.com/book/show/')

# book_urls = [
#              'https://www.goodreads.com/book/show/42201629-marque-of-caine',
#             'https://www.goodreads.com/book/show/43521657-the-ten-thousand-doors-of-january',
#              'https://www.goodreads.com/book/show/34017126-the-stone-sky'
#             #  'https://www.goodreads.com/book/show/37794149-a-memory-called-empire',
#             # 'https://www.goodreads.com/book/show/36510722-gods-of-jade-and-shadow',
#             #  'https://www.goodreads.com/book/show/42036538-gideon-the-ninth',
#             #  'https://www.goodreads.com/book/show/43401925-a-song-for-a-new-day',
#             #  'https://www.goodreads.com/book/show/53128611-anxiety-is-the-dizziness-of-freedom',
#             #  'https://www.goodreads.com/book/show/36546128-the-haunting-of-tram-car-015',
#             #  'https://www.goodreads.com/book/show/43352954-this-is-how-you-lose-the-time-war',
#             #  'https://www.goodreads.com/book/show/40939044-her-silhouette-drawn-in-water',
#             #  'https://www.goodreads.com/book/show/42201962-the-deep',
#             #  'https://www.goodreads.com/book/show/45454304-catfish-lullaby',
#             #  'https://www.goodreads.com/book/show/44287123-uncanny-magazine-issue-27',
#             #  'https://www.goodreads.com/book/show/52579998-carpe-glitter',
#             #  'https://www.goodreads.com/book/show/53429033-the-archronology-of-love',
#             #  'https://www.goodreads.com/book/show/52228003-uncanny-magazine-issue-29',
#             #  'https://www.goodreads.com/book/show/43565763-his-footsteps-through-darkness-and-light',
#             #  'https://www.goodreads.com/book/show/52139451-for-he-can-creep',
#             #  'https://www.goodreads.com/book/show/51205594-the-magazine-of-fantasy-science-fiction-july-august-2019',
#             #  'https://www.goodreads.com/book/show/44092137-clarkesworld-magazine-issue-149',
#             #  'https://www.goodreads.com/book/show/53245653-ten-excerpts-from-an-annotated-bibliography-on-the-cannibal-women-of-rat',
#             #  'https://www.goodreads.com/book/show/53188307-a-catalog-of-storms'
#              ]




# # # Set output directory (include final forward slash!)
# # output_dir = 'data/raw' #this is where your CSV will go at end
# # # Set output name ('.csv' will be automatically appended)
# # output_name = 'reviews_df'

# # Set amount of time to sleep between browser actions (4 seconds is recommended)
# zzz = 4

# %%
# # make urls list of ALL nominees

# # filtering bookIDs so only scrape each bookID once
# import pandas as pd
# import numpy as np

# # awards=pd.read_csv('https://www.dropbox.com/s/oywdtjtpsjge8g2/combo-awards.csv?dl=1')
# awards=pd.read_csv('https://www.dropbox.com/s/95h72pt7biiecgb/combo-awards2.csv?dl=1')
# unique_awards=awards.drop_duplicates(subset=['bookID'])
# unique_awards #scrape this datasets bookLink for reviews

# # make list of urls from bookLink column
# bookurlslist=unique_awards.bookLink.tolist()
# bookurlslist
# bookurls=bookurlslist

# book_urls=[]

# for link in bookurls:
#   book_urls.append('https://www.goodreads.com' +link)




# zzz = 4

# %%
# Out:
# 175176

# %%
pd.set_option('display.max_colwidth', None)
book_urls=str(book_urls)
print(book_urls)
# Out:
# ['https://www.goodreads.com/book/show/43466735-fireside-magazine-issue-52-february-2018', 'https://www.goodreads.com/book/show/34659272-the-only-harmless-great-thing', 'https://www.goodreads.com/book/show/36686547-the-tea-master-and-the-detective', 'https://www.goodreads.com/book/show/33080122-the-calculating-stars', 'https://www.goodreads.com/book/show/35957452-apex-magazine-issue-99', 'https://www.goodreads.com/book/show/33414252-a-human-stain', 'https://www.goodreads.com/book/show/32758901-all-systems-red', 'https://www.goodreads.com/book/show/31817749-the-stone-sky', 'https://www.goodreads.com/book/show/27370017-the-starlit-wood', 'https://www.goodreads.com/book/show/36145729-a-lone-star-in-the-sky', 'https://www.goodreads.com/book/show/25526296-every-heart-a-doorway', 'https://www.goodreads.com/book/show/25372801-all-the-birds-in-the-sky', 'https://www.goodreads.com/book/show/25382762-asimov-s-science-fiction-june-2015', 'https://www.goodreads.com/book/show/26849365-nightmare-ma
# ...

# %% [markdown]
# ## **Scraper**

# %% [markdown]
# ### Scraper Utilities (required to run before scrape)

# %%
# can test it out with just two urls

book_urls=['http://www.worldswithoutend.com/author.asp?ID=1074', 'http://www.worldswithoutend.com/author.asp?ID=672']
zzz = 4

chromepath = webdriver.Chrome('chromedriver',options=options)

# %%
# install chromium, its driver, and selenium
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
wd = webdriver.Chrome('chromedriver',options=options)
# wd.get("https://www.website.com")
# print(wd.page_source)  # results
# Out:
# Hit:1 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# ...

# %%
# STEP 5 scraper utilities (books_df version)

from bs4 import BeautifulSoup
from datetime import datetime
import numpy as np
import time


# Function to load a book's URL
def go_to_page(browser, book_url):
    browser.get(book_url)
    time.sleep(zzz)
    close_pop_up(browser)


# Function to close pesky pop-up message, if present
def close_pop_up(browser):
    pop_up_xpath = '/html/body/div[3]/div/div/div[1]/button/img'
    try:
        browser.find_element_by_xpath(pop_up_xpath).click()
        time.sleep(zzz)
    except:
        pass


# Function to scrape a book's essential info (ID, title, author)
def scrape_book_info(browser, book_url):

    # Download & Soupify webpage
    r = browser.page_source
    soup = BeautifulSoup(r, features = 'html.parser')
    metacol = soup.find(id="metacol")
    details = metacol.find(id="details")
    
    # Find book ID, title, and author
  #  authorName= book_url.split('/')[-1].split('-')[0]
  #   born = soup.find(id='bookTitle').text.replace('\n', '').strip()
  #   occupation = soup.find('a', class_='authorName').text
  #   biography=soup.find_all('p', class_='title')
    
    # try:
    #   # goodreads_author=metacol.find("div", {"class": "authorName__container"}).get("span")
    #   # goodreads_author= metacol.find(id= "meta", {"itemprop": "reviewCount"}).get("content")             
    # # goodreads_author = metacol.find(id="bookAuthors").find_all("span")[3].text.strip() 
    #     # goodreads_author=metacol.find(id='bookAuthors').find_all("span")[3].text.strip('()')
    try:
      authorName= soup.find("div", {"bookDataBox": ""}).get("isbn")

    except:
      authorName=None


    try:
      born = soup.find("div", {"bookDataBox": ""}).get("isbn")
    except:
      born=None
    
    #ASIN
    try:
      # # asin=soup.find("div", {"bookDataBox": ""}).get("isbn")
      # # asin=soup.find("div", {"class": "bookAuthorProfile__about"}).text
      # # asin =soup.find(id="bookDataBox", {"infoBoxRowItem": "itemprop"}).get("isbn")
      # # asin = details.find('bookDataBox', {"clearFloats": "infoBoxRowItem"}).text
      # # asin=details.find(id='bookDataBox').find_all("div:clearFloats")[1].get("isbn")
      # # asin=soup.find('div', {'clearFloats': 'infoBoxRowItem'}).get('isbn')
      # asin=metacol.find("div", {"itemprop": "isbn"}).text
      occupation=soup.find("div", {"bookDataBox": ""}).get("isbn")

    except:
      occupation=None


    try:
      nationality=soup.find("div", {"bookDataBox": ""}).get("isbn")

    except:
      nationality=None

     #isbn
    try:
        # isbn = str(soup.find("meta", {"property": "books:isbn"}).get("content"))
        # isbn= meta[property='books:isbn']")[0]['content']
      biography=soup.find("div", {"bookDataBox": ""}).get("isbn")
       
        # isbn=soup.select("meta[property='books:isbn']")[0]['content'],"\n",

      	# isbn = str(soup.find("meta", {"property": "books:isbn"})[0].get("content"))
        # isbn=str(metacol.find("div", {"clearFloats": "::after"}).text)
    except:
	    biography=None


    return authorName, born, occupation, nationality, biography

# %% [markdown]
# ### Scrape Author Info!

# %%
# STEP 6 scrape (books_df version)

import os
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import ElementNotVisibleException

# Initialize dataframe to store review data
books_df = pd.DataFrame()
# Initialize browser
browser = webdriver.Chrome('chromedriver',options=options)


# # Loop through each book in list
for book_url in book_urls:

    # Go to book's URL
    go_to_page(browser, book_url)

    # Download & Soupify webpage
    r = browser.page_source
    soup = BeautifulSoup(r, features = 'html.parser')
    metacol = soup.find(id="metacol")
    # details = metacol.find(id="details")
    
    # Find book ID, title, and author
  #  authorName= book_url.split('/')[-1].split('-')[0]
  #   born = soup.find(id='bookTitle').text.replace('\n', '').strip()
  #   occupation = soup.find('a', class_='authorName').text
  #   biography=soup.find_all('p', class_='title')
    
    # try:
    #   # goodreads_author=metacol.find("div", {"class": "authorName__container"}).get("span")
    #   # goodreads_author= metacol.find(id= "meta", {"itemprop": "reviewCount"}).get("content")             
    # # goodreads_author = metacol.find(id="bookAuthors").find_all("span")[3].text.strip() 
    #     # goodreads_author=metacol.find(id='bookAuthors').find_all("span")[3].text.strip('()')
    try:
      # authorName= soup.find('div', id='mainbody')
      # print( ''.join(map(str, div.contents)))
      # soup = BeautifulSoup(data)
      # authorName=soup.find('div', id='mainbody')
      # authorName= authorName.find('td')
      # authorName= authorName.contents[0]
      # authorName = authorName.strip()
      # authorName=soup.find_all('tr')[1:]
      # authorName=authorName.td.text
      # authorName=soup.findAll('table')[1].findAll('tr')
     authorName=soup.find("td", text="Full Name:").find_next_sibling("td").text


    except:
      authorName=None

    try:
      born =soup.find("td", text="Born:").find_next_sibling("td").text
      
    
    except:
      born=None
    
    #ASIN
    try:
      # # asin=soup.find("div", {"bookDataBox": ""}).get("isbn")
      # # asin=soup.find("div", {"class": "bookAuthorProfile__about"}).text
      # # asin =soup.find(id="bookDataBox", {"infoBoxRowItem": "itemprop"}).get("isbn")
      # # asin = details.find('bookDataBox', {"clearFloats": "infoBoxRowItem"}).text
      # # asin=details.find(id='bookDataBox').find_all("div:clearFloats")[1].get("isbn")
      # # asin=soup.find('div', {'clearFloats': 'infoBoxRowItem'}).get('isbn')
      # asin=metacol.find("div", {"itemprop": "isbn"}).text
      occupation=soup.find("td", text="Occupation:").find_next_sibling("td").text

    except:
      occupation=None


    try:
      nationality=soup.find("td", text="Nationality:").find_next_sibling("td").text

    except:
      nationality=None

     #isbn
    try:
        # isbn = str(soup.find("meta", {"property": "books:isbn"}).get("content"))
        # isbn= meta[property='books:isbn']")[0]['content']
      biography=soup.find_all('h3')
      biography=biography.find('p').text
       
        # isbn=soup.select("meta[property='books:isbn']")[0]['content'],"\n",

      	# isbn = str(soup.find("meta", {"property": "books:isbn"})[0].get("content"))
        # isbn=str(metacol.find("div", {"clearFloats": "::after"}).text)
    except:
	    biography=None

    # Scrape the book's essential info
    authorName, born, occupation, nationality, biography  

        # Create dataframe of review data
  
    scrape_df = pd.Series([authorName, born, occupation, nationality, biography])


    #             # Append review data to master dataframe
    books_df = books_df.append(scrape_df, ignore_index = True)


# Rename columns of reviews dataframe
books_df.columns = ['authorName', 'born', 'occupation', 'nationality', 'biography']


# books_df.rating_count=books_df.rating_count.astype(int)
# books_df.review_count=books_df.review_count.astype(int)
# books_df.pages=books_df.pages.astype(str)
# books_df.pages=books_df.pages.str.extract('(\d+)')


# books_df.author_followers=books_df.author_followers.str.extract('(\d+)')

# # 1 and 0 for goodreads
# books_df['goodreads_author2'] = books_df['goodreads_author'].apply(lambda i : 1 if i == 'Goodreads Author' else 0)
# del books_df['goodreads_author']


# # 1 and 0 for goodreads
# books_df['book_series2'] = books_df['book_series'].apply(lambda i : 0 if i == None else 1)
# del books_df['book_series']

# books_df.rename(columns={'book_id': 'bookID', 'review_count': 'text_reviews_count', 'rating_average': 'average_rating', 'book_author': 'authorName', 'book_title': 'bookTitle', 
#                          'book_format': 'format', 'rating_count': 'ratings_count', 'pages': 'num_pages', 'goodreads_author2': 'goodreads_author', 'book_series2': 'book_series'}, inplace=True)

# books_df['author_followers']=books_df['author_followers'].str.replace('\\','')
# books_df['author_followers']=books_df['author_followers'].str.replace('\n','')
# books_df['author_followers']=books_df['author_followers'].str.replace('n','')
# books_df['author_followers']=books_df['author_followers'].str.replace(',','')
# books_df['author_followers']=books_df['author_followers'].str.replace('followers','')
# books_df['author_followers']=books_df['author_followers'].str.replace('follower','')
# # books_df['author_followers']=books_df['author_followers'].astype(int)

# # books_df['publication_year']=books_df['publication_year'].astype(int)
# # books_df['num_pages']=books_df['num_pages'].astype(int)

# books_df['author_bio']=books_df['author_bio'].str.replace('\n','')
# # books_df['author_followers']=books_df['author_followers'].str.replace('\n','')
# # books_df['author_followers']=books_df['author_followers'].str.replace('n','')
# # books_df['author_followers']=books_df['author_followers'].str.replace(',','')
# # books_df['author_followers']=books_df['author_followers'].str.replace('followers','')
# # books_df['author_followers']=books_df['author_followers'].astype(int)

# # books_df['n_comments']=books_df['n_comments'].astype(int)
# # books_df['num_pages']=books_df['num_pages'].astype(int)

# del books_df['genres']

# # drop duplicates
# books_df=books_df.drop_duplicates(subset=['bookID'], keep=False)

books_df.authorName=books_df.authorName.str.replace("\n", " ")

# get year
#'\d{4}'

# save to csv
books_df.to_csv('author_stats2.csv')

#audio to hear when scraping done
from google.colab import output
output.eval_js('new Audio("https://ssl.gstatic.com/dictionary/static/sounds/20180430/complete--_us_1.mp3").play()')

books_df
# Out:
#            authorName  ... biography
# 0     Daniel  Abraham  ...      None
# 1  Stephen Edwin King  ...      None
#
# [2 rows x 5 columns]
